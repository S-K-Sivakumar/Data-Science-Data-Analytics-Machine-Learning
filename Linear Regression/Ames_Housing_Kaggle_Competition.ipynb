# %% [markdown]
# # Kaggle Competition Test File Submission

# %%
# %run "C:/Users/ssiva/OneDrive/Documents/Machine_Learning/Machine_Learning/Machine_Learning_Algorithms/Machine_Learning_Algorithms.ipynb"
# Out:
# Available functions:
#
#
# create_random_df(model,nrows,ncols,nclasses,target_multiplier = 1),
#
# find_cols_to_ignore(df,thresh_cat = 0.02,cols_to_ignore = None),
#
# impute_cols(df,k=None,thresh_null_cat = 0.02,cols_to_ignore = None),
#
# num_unique_values_in_cols(df,cols = None),
#
# remove_outliers(df_in,outlier_cols,thresh_cat = 0.02,remove = True),
#
# convert_cat(df, cat_cols,output_col=None),
#
# normalize(df,cols_to_ignore = None,target_col = None),
#
# split_df(df,test_size = 0.3,df_to_return = 'df_train'),
#
# shuffled_split_dfs(df,test_size = 0.3),
#
# check_accuracy(df = None,pred_df = None, test_df = None, algo = 'lin',target_class = None),
#
# stoch_grad_desc(dataset,output_col,cols_to_ignore = None,alpha = 0.1,epoch = 10,algo = 'lin',initial_coeffs = 1),
#
# make_predictions(dataset, coeff_list, output_col,cols_to_ignore = None,algo = 'lin'),
#
# knn(df_train,new_pts_list,dep_col,k = 7,only_pred_df = True),
#
# kmeans(df,k=3,epoch = 1),
#
# cart(df)
#
#
# ...

# %%
housing = pd.read_csv(r"Ames_housing_train.csv")

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
housing.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
housing.head(2)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
#
# [2 rows x 81 columns]

# %% [markdown]
# ### Null Value Treatment

# %%
housing.isnull().sum()[housing.isnull().sum() != 0].sort_values(ascending = False)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# dtype: int64

# %% [markdown]
# #### Dropping the 'PoolQC', 'MiscFeature', and 'Alley' columns since they have a large number of null values

# %%
housing.drop(['PoolQC','MiscFeature','Alley'],axis = 1,inplace = True)

# %% [markdown]
# ### Treating all other null value columns

# %%
clean_housing = impute_cols(housing,cols_to_ignore=['SalePrice'])
# Out:
# C:\Users\ssiva\Anaconda3\lib\site-packages\ipykernel_launcher.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Program took 0.0 hr(s), 0.0 min(s), 6.659195899963379 sec(s) to run
# Program took 0.0 hr(s), 0.0 min(s), 5.3148016929626465 sec(s) to run
# Program took 0.0 hr(s), 0.0 min(s), 0.8886239528656006 sec(s) to run
# Program took 0.0 hr(s), 0.0 min(s), 1.2048537731170654 sec(s) to run
# Program took 0.0 hr(s), 0.0 min(s), 0.5754959583282471 sec(s) to run
# Program took 0.0 hr(s), 0.0 min(s), 0.4757242202758789 sec(s) to run
# Program took 0.0 hr(s), 0.0 min(s), 0.2094113826751709 sec(s) to run
# Program took 0.0 hr(s), 0.0 min(s), 0.22842192649841309 sec(s) to run
# Program took 0.0 hr(s), 0.0 min(s), 0.27429652214050293 sec(s) to run
# ...

# %%
ames_train = clean_housing

# %%
ames_test = pd.read_csv(r'Ames_housing_test.csv')

# %%
ames_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
ames_test.drop(['PoolQC','MiscFeature','Alley'],axis = 1,inplace = True)

# %%
ames_test_ids = ames_test['Id']

# %%
ames_train.set_index('Id',inplace = True)

# %%
ames_test.set_index('Id',inplace = True)

# %%
ames_test['SalePrice'] = 0

# %% [markdown]
# ### Appending test dataframe to train dataframe

# %%
ames = ames_train.append(ames_test)

# %%
ames.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# Id
# 1           60       RL         65.0     8450   Pave      Reg         Lvl
# 2           20       RL         80.0     9600   Pave      Reg         Lvl
# 3           60       RL         68.0    11250   Pave      IR1         Lvl
# 4           70       RL         60.0     9550   Pave      IR1         Lvl
# 5           60       RL         84.0    14260   Pave      IR1         Lvl
#
#    Utilities LotConfig LandSlope    ...    3SsnPorch ScreenPorch PoolArea  \
# Id                                  ...
# 1     AllPub    Inside       Gtl    ...            0           0        0
# 2     AllPub       FR2       Gtl    ...            0           0        0
# 3     AllPub    Inside       Gtl    ...            0           0        0
# 4     AllPub    Corner       Gtl    ...            0           0        0
# 5     AllPub       FR2       Gtl    ...            0           0        0
#
# ...

# %% [markdown]
# ### Normalizing Continuous Columns

# %%
cols_to_ignore = find_cols_to_ignore(ames_train,cols_to_ignore='SalePrice')

# %%
norm_ames = normalize(ames,cols_to_ignore=cols_to_ignore)

# %% [markdown]
# ### Outlier Treatment (replacing outlier values)

# %%
ames_no_outliers = remove_outliers(norm_ames,remove=False)

# %%
ames_no_outliers.tail()
# Out:
#       MSSubClass MSZoning  LotFrontage   LotArea Street LotShape LandContour  \
# Id
# 2915         160       RM     0.030822  0.002973   Pave      Reg         Lvl
# 2916         160       RM     0.030822  0.002776   Pave      Reg         Lvl
# 2917          20       RL     0.304795  0.076693   Pave      Reg         Lvl
# 2918          85       RL     0.140411  0.042726   Pave      Reg         Lvl
# 2919          60       RL     0.181507  0.038921   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope    ...    3SsnPorch ScreenPorch PoolArea  \
# Id                                    ...
# 2915    AllPub    Inside       Gtl    ...            0         0.0        0
# 2916    AllPub    Inside       Gtl    ...            0         0.0        0
# 2917    AllPub    Inside       Gtl    ...            0         0.0        0
# 2918    AllPub    Inside       Gtl    ...            0         0.0        0
# 2919    AllPub    Inside       Mod    ...            0         0.0        0
# ...

# %% [markdown]
# ### Null Value treatment for joined dataset

# %%
ames_imputed = impute_cols(ames_no_outliers)
# Out:
# C:\Users\ssiva\Anaconda3\lib\site-packages\ipykernel_launcher.py:117: RuntimeWarning: divide by zero encountered in true_divide
# C:\Users\ssiva\Anaconda3\lib\site-packages\ipykernel_launcher.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Program took 0.0 hr(s), 0.0 min(s), 10.577727317810059 sec(s) to run
# Program took 0.0 hr(s), 0.0 min(s), 5.959754228591919 sec(s) to run
# Program took 0.0 hr(s), 0.0 min(s), 0.6312549114227295 sec(s) to run
# Program took 0.0 hr(s), 0.0 min(s), 0.6545934677124023 sec(s) to run
# Program took 0.0 hr(s), 0.0 min(s), 0.6484417915344238 sec(s) to run
# Program took 0.0 hr(s), 0.0 min(s), 0.6489098072052002 sec(s) to run
# Program took 0.0 hr(s), 0.0 min(s), 0.41033029556274414 sec(s) to run
# ...

# %%
ames_imputed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 77 columns):
# MSSubClass       2919 non-null int64
# MSZoning         2919 non-null object
# LotFrontage      2919 non-null float64
# LotArea          2919 non-null float64
# Street           2919 non-null object
# LotShape         2919 non-null object
# LandContour      2919 non-null object
# Utilities        2919 non-null object
# LotConfig        2919 non-null object
# LandSlope        2919 non-null object
# Neighborhood     2919 non-null object
# Condition1       2919 non-null object
# Condition2       2919 non-null object
# BldgType         2919 non-null object
# HouseStyle       2919 non-null object
# OverallQual      2919 non-null int64
# OverallCond      2919 non-null int64
# YearBuilt        2919 non-null float64
# YearRemodAdd     2919 non-null float64
# RoofStyle        2919 non-null object
# RoofMatl         2919 non-null object
# Exterior1st      2919 non-null object
# ...

# %%
cols_to_ignore.remove('SalePrice')

# %% [markdown]
# ### Converting Categorical Variables

# %%
ames_converted = convert_cat(ames_imputed,cat_cols = cols_to_ignore,output_col = 'SalePrice')

# %%
ames_converted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Columns: 427 entries, LotFrontage to SalePrice
# dtypes: float64(19), uint8(408)
# memory usage: 1.7 MB

# %%
ames_converted.loc[1458:1461]
# Out:
#       LotFrontage   LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# Id
# 1458     0.154110  0.036187   0.500000      0.933333         0.0    0.048724
# 1459     0.160959  0.039342   0.565217      0.766667         0.0    0.008682
# 1460     0.184932  0.040370   0.673913      0.250000         0.0    0.147059
# 1461     0.202055  0.048246   0.644928      0.183333         0.0    0.082920
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF    ...      YrSold__2007  \
# Id                                                    ...
# 1458         0.0   0.375428     0.188543  0.179374    ...                 0
# 1459         0.0   0.000000     0.176432  0.156270    ...                 0
# 1460         0.0   0.058219     0.205565  0.193657    ...                 0
# 1461         0.0   0.115582     0.144354  0.118042    ...                 0
#
#       YrSold__2008  YrSold__2009  YrSold__2010  Foundation__CBlock  \
# Id
# ...

# %%
ames_converted.tail()
# Out:
#       LotFrontage   LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# Id
# 2915     0.030822  0.002973   0.710145      0.333333     0.00000    0.000000
# 2916     0.030822  0.002776   0.710145      0.333333     0.00000    0.044649
# 2917     0.304795  0.076693   0.637681      0.766667     0.00000    0.216867
# 2918     0.140411  0.042726   0.869565      0.700000     0.00000    0.059709
# 2919     0.181507  0.038921   0.876812      0.733333     0.05875    0.134302
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF    ...      YrSold__2007  \
# Id                                                    ...
# 2915         0.0   0.233733     0.089362  0.044528    ...                 0
# 2916         0.0   0.125856     0.089362  0.044528    ...                 0
# 2917         0.0   0.000000     0.200327  0.186936    ...                 0
# 2918         0.0   0.246147     0.149264  0.133585    ...                 0
# ...

# %% [markdown]
# ### Separating ames dataframe into labeled and unlabeled dataframes

# %%
ames_labeled = ames_converted.loc[1:1460]

# %%
ames_unlabeled = ames_converted.loc[1461:]

# %%
ames_labeled.tail()
# Out:
#       LotFrontage   LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# Id
# 1456     0.140411  0.030929   0.920290      0.833333    0.000000    0.000000
# 1457     0.219178  0.055505   0.768116      0.633333    0.074375    0.139972
# 1458     0.154110  0.036187   0.500000      0.933333    0.000000    0.048724
# 1459     0.160959  0.039342   0.565217      0.766667    0.000000    0.008682
# 1460     0.184932  0.040370   0.673913      0.250000    0.000000    0.147059
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF    ...      YrSold__2007  \
# Id                                                    ...
# 1456         0.0   0.407962     0.155974  0.130015    ...                 1
# 1457         0.0   0.252140     0.252373  0.365259    ...                 0
# 1458         0.0   0.375428     0.188543  0.179374    ...                 0
# 1459         0.0   0.000000     0.176432  0.156270    ...                 0
# ...

# %%
ames_unlabeled.head()
# Out:
#       LotFrontage   LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# Id
# 1461     0.202055  0.048246   0.644928      0.183333      0.0000    0.082920
# 1462     0.205479  0.060609   0.623188      0.133333      0.0675    0.163536
# 1463     0.181507  0.058566   0.905797      0.800000      0.0000    0.140149
# 1464     0.195205  0.040562   0.913043      0.800000      0.0125    0.106662
# 1465     0.075342  0.017318   0.869565      0.700000      0.0000    0.046598
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF    ...      YrSold__2007  \
# Id                                                    ...
# 1461         0.0   0.115582     0.144354  0.118042    ...                 0
# 1462         0.0   0.173801     0.217512  0.208990    ...                 0
# 1463         0.0   0.058647     0.151882  0.124764    ...                 0
# 1464         0.0   0.138699     0.151555  0.124344    ...                 0
# ...

# %%
ames_unlabeled.tail()
# Out:
#       LotFrontage   LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# Id
# 2915     0.030822  0.002973   0.710145      0.333333     0.00000    0.000000
# 2916     0.030822  0.002776   0.710145      0.333333     0.00000    0.044649
# 2917     0.304795  0.076693   0.637681      0.766667     0.00000    0.216867
# 2918     0.140411  0.042726   0.869565      0.700000     0.00000    0.059709
# 2919     0.181507  0.038921   0.876812      0.733333     0.05875    0.134302
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF    ...      YrSold__2007  \
# Id                                                    ...
# 2915         0.0   0.233733     0.089362  0.044528    ...                 0
# 2916         0.0   0.125856     0.089362  0.044528    ...                 0
# 2917         0.0   0.000000     0.200327  0.186936    ...                 0
# 2918         0.0   0.246147     0.149264  0.133585    ...                 0
# ...

# %% [markdown]
# ### Creating train/test dataframes from labeled dataframe

# %%
ames_lab_train,ames_lab_test = shuffled_split_dfs(ames_labeled)

# %%
ames_coeffs = stoch_grad_desc(ames_lab_train,output_col = 'SalePrice',alpha = 0.0005,epoch = 40)
# Out:
# Program took 0.0 hr(s), 3.0 min(s), 16.050018787384033 sec(s) to run

# %%
ames_predictions = make_predictions(ames_lab_test,ames_coeffs,output_col = 'SalePrice')

# %%
ames_predictions.head()
# Out:
#       LotFrontage   LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 1021     0.191781  0.040501   0.971014      0.950000     0.21250    0.203756
# 1022     0.160959  0.044778   0.565217      0.000000     0.00000    0.184266
# 1023     0.167808  0.033186   0.615942      0.116667     0.00000    0.033487
# 1024     0.304795  0.060436   0.978261      0.950000     0.25625    0.000000
# 1025     0.174658  0.044301   0.695652      0.300000     0.00000    0.000000
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF      ...        \
# 1021         0.0   0.135274     0.239935  0.237765      ...
# 1022         0.0   0.053082     0.190507  0.174333      ...
# 1023         0.0   0.268836     0.241899  0.240286      ...
# 1024         0.0   0.670377     0.256301  0.265911      ...
# 1025         0.0   0.720783     0.289362  0.301197      ...
#
#       YrSold__2008  YrSold__2009  YrSold__2010  Foundation__CBlock  \
# ...

# %%
check_accuracy(ames_predictions)
# Out:
# {'MAE': 19748.890537623844,
#  'ME': 2379.842658884334,
#  'MSE': 778749785.2897187,
#  'RMSE': 27906.088695654194,
#  'r_sqd': 0.8415564944659569}

# %% [markdown]
# ### Now I will use the full labeled dataset to find the optimal coefficients

# %%
final_coeffs = stoch_grad_desc(ames_labeled,output_col = 'SalePrice',alpha = 0.003,epoch = 150)
# Out:
# Program took 0.0 hr(s), 16.0 min(s), 58.026901960372925 sec(s) to run

# %%
check_predictions = make_predictions(ames_lab_test,final_coeffs,output_col='SalePrice')

# %%
check_accuracy(check_predictions)
# Out:
# {'MAE': 12240.627671499327,
#  'ME': -221.11746736094315,
#  'MSE': 296149295.4183044,
#  'RMSE': 17208.988826142704,
#  'r_sqd': 0.9397458164177134}

# %%
check_predictions.head(10)
# Out:
#       LotFrontage   LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 1022     0.160959  0.044778   0.565217      0.000000    0.000000    0.184266
# 1023     0.167808  0.033186   0.615942      0.116667    0.000000    0.033487
# 1024     0.304795  0.060436   0.978261      0.950000    0.256250    0.000000
# 1025     0.174658  0.044301   0.695652      0.300000    0.000000    0.000000
# 1026     0.195205  0.046947   0.623188      0.133333    0.112500    0.081502
# 1027     0.126712  0.023744   0.362319      0.000000    0.000000    0.000000
# 1028     0.304795  0.063114   0.978261      0.966667    0.256250    0.289865
# 1029     0.167808  0.043483   0.760870      0.850000    0.017500    0.212615
# 1030     0.304795  0.063928   0.971014      0.950000    0.190000    0.239192
# 1031     0.226027  0.040665   0.652174      0.200000    0.163125    0.000000
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF      ...        \
# ...

# %% [markdown]
# ### Now that the coefficients are calculated, I will make predictions for the test dataset

# %%
final_predictions = make_predictions(ames_unlabeled,final_coeffs,'SalePrice')

# %%
final_predictions.head(10)
# Out:
#       LotFrontage   LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# Id
# 1461     0.202055  0.048246   0.644928      0.183333      0.0000    0.082920
# 1462     0.205479  0.060609   0.623188      0.133333      0.0675    0.163536
# 1463     0.181507  0.058566   0.905797      0.800000      0.0000    0.140149
# 1464     0.195205  0.040562   0.913043      0.800000      0.0125    0.106662
# 1465     0.075342  0.017318   0.869565      0.700000      0.0000    0.046598
# 1466     0.184932  0.040665   0.876812      0.733333      0.0000    0.000000
# 1467     0.000000  0.031223   0.869565      0.950000      0.0000    0.165663
# 1468     0.143836  0.033195   0.913043      0.800000      0.0000    0.000000
# 1469     0.219178  0.041487   0.855072      0.666667      0.0000    0.112863
# 1470     0.167808  0.033186   0.710145      0.333333      0.0000    0.142452
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF      ...        \
# ...

# %%
final_pred_df = final_predictions[['Prediction']]

# %%
final_pred_df.head(10)
# Out:
#          Prediction
# Id
# 1461  119110.940244
# 1462  168563.658104
# 1463  180966.672219
# 1464  195546.304490
# 1465  196111.480827
# 1466  165959.158443
# 1467  177292.956237
# 1468  161537.168472
# 1469  193709.883026
# 1470  136144.778905

# %%
final_pred_df.rename({'Prediction':'SalePrice'},axis = 1,inplace = True)
# Out:
# C:\Users\ssiva\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
final_pred_df.head()
# Out:
#           SalePrice
# Id
# 1461  119110.940244
# 1462  168563.658104
# 1463  180966.672219
# 1464  195546.304490
# 1465  196111.480827

# %% [markdown]
# ### Writing Submission File

# %%
final_pred_df.to_csv('ames_submission_2.csv')
