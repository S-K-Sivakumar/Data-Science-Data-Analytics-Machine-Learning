# %% [markdown]
# # Line DF

# %%
line_df = pd.read_csv(r'C:\Users\ssiva\OneDrive\Documents\Machine Learning_\Machine Learning\novel-corona-virus-2019-dataset\COVID19_line_list_data.csv')

# %%
line_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 27 columns):
# id                       1085 non-null int64
# case_in_country          888 non-null float64
# reporting date           1084 non-null object
# Unnamed: 3               0 non-null float64
# summary                  1080 non-null object
# location                 1085 non-null object
# country                  1085 non-null object
# gender                   902 non-null object
# age                      843 non-null float64
# symptom_onset            563 non-null object
# If_onset_approximated    560 non-null float64
# hosp_visit_date          507 non-null object
# exposure_start           128 non-null object
# exposure_end             341 non-null object
# visiting Wuhan           1085 non-null int64
# from Wuhan               1081 non-null float64
# death                    1085 non-null object
# recovered                1085 non-null object
# ...

# %%
line_df.describe()
# Out:
#                 id  case_in_country  Unnamed: 3         age  \
# count  1085.000000       888.000000         0.0  843.000000
# mean    543.000000        48.841216         NaN   49.483689
# std     313.356825        78.853528         NaN   18.255334
# min       1.000000         1.000000         NaN    0.250000
# 25%     272.000000        11.000000         NaN   35.000000
# 50%     543.000000        28.000000         NaN   51.000000
# 75%     814.000000        67.250000         NaN   64.000000
# max    1085.000000      1443.000000         NaN   96.000000
#
#        If_onset_approximated  visiting Wuhan   from Wuhan  Unnamed: 21  \
# count             560.000000     1085.000000  1081.000000          0.0
# mean                0.042857        0.176959     0.144311          NaN
# std                 0.202716        0.381810     0.351567          NaN
# min                 0.000000        0.000000     0.000000          NaN
# ...

# %%
line_df.head(1)
# Out:
#    id  case_in_country reporting date  Unnamed: 3  \
# 0   1              NaN      1/20/2020         NaN
#
#                                              summary             location  \
# 0  First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
#
#   country gender   age symptom_onset     ...      recovered symptom  \
# 0   China   male  66.0      01/03/20     ...              0     NaN
#
#                                  source  \
# 0  Shenzhen Municipal Health Commission
#
#                                                 link  Unnamed: 21  \
# 0  http://wjw.sz.gov.cn/wzx/202001/t20200120_1898...          NaN
#
#    Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26
# 0          NaN         NaN         NaN         NaN         NaN
#
# [1 rows x 27 columns]

# %%
line_df.groupby('country').count().sort_values(by = 'id',ascending = 0)
# Out:
#                  id  case_in_country  reporting date  summary  location  age  \
# country
# Mainland China  197                0             197      193       197  190
# Japan           190              190             189      189       190  186
# South Korea     114              114             114      114       114   92
# Hong Kong        94               94              94       94        94   93
# Singapore        93               93              93       93        93   90
# Germany          54               54              54       54        54   14
# Thailand         41               41              41       41        41   18
# France           39               39              39       39        39   18
# Spain            34               34              34       34        34   21
# Taiwan           34               34              34       34        34   31
# Malaysia         23               23              23       23        23   23
# ...

# %%
line_df.isna().sum()
# Out:
# id                          0
# case_in_country           197
# reporting date              1
# Unnamed: 3               1085
# summary                     5
# location                    0
# country                     0
# gender                    183
# age                       242
# symptom_onset             522
# If_onset_approximated     525
# hosp_visit_date           578
# exposure_start            957
# exposure_end              744
# visiting Wuhan              0
# from Wuhan                  4
# death                       0
# recovered                   0
# symptom                   815
# source                      0
# link                        0
# Unnamed: 21              1085
# Unnamed: 22              1085
# Unnamed: 23              1085
# Unnamed: 24              1085
# Unnamed: 25              1085
# Unnamed: 26              1085
# dtype: int64

# %%
line_df.dropna(axis = 1,thresh = 150,inplace = True)

# %%
line_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 19 columns):
# id                       1085 non-null int64
# case_in_country          888 non-null float64
# reporting date           1084 non-null object
# summary                  1080 non-null object
# location                 1085 non-null object
# country                  1085 non-null object
# gender                   902 non-null object
# age                      843 non-null float64
# symptom_onset            563 non-null object
# If_onset_approximated    560 non-null float64
# hosp_visit_date          507 non-null object
# exposure_end             341 non-null object
# visiting Wuhan           1085 non-null int64
# from Wuhan               1081 non-null float64
# death                    1085 non-null object
# recovered                1085 non-null object
# symptom                  270 non-null object
# source                   1085 non-null object
# ...

# %%
line_df.describe()
# Out:
#                 id  case_in_country         age  If_onset_approximated  \
# count  1085.000000       888.000000  843.000000             560.000000
# mean    543.000000        48.841216   49.483689               0.042857
# std     313.356825        78.853528   18.255334               0.202716
# min       1.000000         1.000000    0.250000               0.000000
# 25%     272.000000        11.000000   35.000000               0.000000
# 50%     543.000000        28.000000   51.000000               0.000000
# 75%     814.000000        67.250000   64.000000               0.000000
# max    1085.000000      1443.000000   96.000000               1.000000
#
#        visiting Wuhan   from Wuhan
# count     1085.000000  1081.000000
# mean         0.176959     0.144311
# std          0.381810     0.351567
# min          0.000000     0.000000
# 25%          0.000000     0.000000
# 50%          0.000000     0.000000
# 75%          0.000000     0.000000
# max          1.000000     1.000000

# %%
line_df.head(2)
# Out:
#    id  case_in_country reporting date  \
# 0   1              NaN      1/20/2020
# 1   2              NaN      1/20/2020
#
#                                              summary             location  \
# 0  First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1  First confirmed imported COVID-19 pneumonia pa...             Shanghai
#
#   country  gender   age symptom_onset  If_onset_approximated hosp_visit_date  \
# 0   China    male  66.0      01/03/20                    0.0        01/11/20
# 1   China  female  56.0     1/15/2020                    0.0       1/15/2020
#
#   exposure_end  visiting Wuhan  from Wuhan death recovered symptom  \
# 0     01/04/20               1         0.0     0         0     NaN
# 1     01/12/20               0         1.0     0         0     NaN
#
#                                               source  \
# 0               Shenzhen Municipal Health Commission
# 1  Official Weibo of Shanghai Municipal Health Co...
#
# ...

# %%
line_df = pd.get_dummies(line_df,drop_first = True,columns = ['gender'])

# %%
line_df['country'].value_counts()
# Out:
# China          197
# Japan          190
# South Korea    114
# Hong Kong       94
# Singapore       93
# Germany         54
# Thailand        41
# France          39
# Spain           34
# Taiwan          34
# Malaysia        23
# UAE             21
# UK              20
# USA             18
# Iran            18
# Bahrain         17
# Vietnam         16
# Australia       15
# Canada          12
# Kuwait           9
# Italy            3
# Phillipines      3
# India            3
# Austria          2
# Russia           2
# Afghanistan      1
# Belgium          1
# Cambodia         1
# Nepal            1
# Croatia          1
# Finland          1
# Lebanon          1
# Algeria          1
# Egypt            1
# Sri Lanka        1
# Israel           1
# Sweden           1
# Switzerland      1
# Name: country, dtype: int64

# %%
top_c = list(line_df[line_df['country'].isin(top_countries_list)]['country'].value_counts().index)
replace_names = []
for country in top_countries_list:
    if country not in top_c:
        replace_names.append(country)
len(replace_names)
# Out:
# 22

# %%
d_top_line_to_corona = {'No_data':['Netherlands','Turkey','Brazil','Portugal','Indonesia','Denmark','Ecuador','Romania','Ireland','Greece','Norway','Poland','Morocco','Czech Republic','Peru','Panama','Mexico','Luxemburg'],'China':'Mainland China','USA':'US','Phiipines':'Philippines'}

# %%
line_df
# Out:
#         id  case_in_country reporting date  \
# 0        1              NaN      1/20/2020
# 1        2              NaN      1/20/2020
# 2        3              NaN      1/21/2020
# 3        4              NaN      1/21/2020
# 4        5              NaN      1/21/2020
# 5        6              NaN      1/21/2020
# 6        7              NaN      1/21/2020
# 7        8              NaN      1/21/2020
# 8        9              NaN      1/21/2020
# 9       10              NaN      1/21/2020
# 10      11              NaN      1/21/2020
# 11      12              NaN      1/21/2020
# 12      13              NaN      1/21/2020
# 13      14              NaN      1/21/2020
# 14      15              NaN      1/22/2020
# 15      16              NaN      1/22/2020
# 16      17              NaN      1/22/2020
# 17      18              NaN      1/22/2020
# 18      19              NaN      1/22/2020
# 19      20              NaN      1/22/2020
# 20      21              NaN      1/22/2020
# ...

# %%
for k,v in d_top_line_to_corona.items():
    if k == 'No_data':
        for country in v:
            line_df = line_df.append(pd.DataFrame(data = [[np.nan,np.nan,np.nan,np.nan,np.nan,country,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan]],columns = line_df.columns))
    elif k != 'No_data':
        line_df['country'] = line_df['country'].apply(lambda country: v if country == k else country)

# %%
line_df[line_df['country'] == 'Netherlands']
# Out:
#    id  case_in_country reporting date summary location      country  age  \
# 0 NaN              NaN            NaN     NaN      NaN  Netherlands  NaN
#
#   symptom_onset  If_onset_approximated hosp_visit_date exposure_end  \
# 0           NaN                    NaN             NaN          NaN
#
#    visiting Wuhan  from Wuhan death recovered symptom source link  gender_male
# 0             NaN         NaN   NaN       NaN     NaN    NaN  NaN          NaN

# %%
line_df.groupby('country').mean()
# Out:
#                     id  case_in_country        age  If_onset_approximated  \
# country
# Afghanistan     1082.0         1.000000  35.000000                    NaN
# Algeria         1083.0         1.000000        NaN                    NaN
# Australia        774.0         8.000000  42.000000               0.111111
# Austria         1080.5         1.500000  24.000000                    NaN
# Bahrain         1071.0         9.000000        NaN                    NaN
# Belgium         1032.0         1.000000        NaN                    NaN
# Brazil             NaN              NaN        NaN                    NaN
# Cambodia         794.0         1.000000  60.000000               0.000000
# Canada           787.5         6.500000  42.583333               0.500000
# Croatia         1084.0         1.000000        NaN                    NaN
# Czech Republic     NaN              NaN        NaN                    NaN
# ...

# %%
top_c = list(line_df[line_df['country'].isin(top_countries_list)]['country'].value_counts().index)
replace_names_check_2 = []
for country in top_countries_list:
    if country not in top_c:
        replace_names.append(country)
replace_names_check_2
# Out:
# []

# %%
line_df['country'] = line_df['country'].apply(lambda country: 'Mainland China' if country == 'China' else country)
line_df['country'] = line_df['country'].apply(lambda country: 'US' if country == 'USA' else country)

# %%
line_df.head()
# Out:
#     id  case_in_country reporting date  \
# 0  1.0              NaN      1/20/2020
# 1  2.0              NaN      1/20/2020
# 2  3.0              NaN      1/21/2020
# 3  4.0              NaN      1/21/2020
# 4  5.0              NaN      1/21/2020
#
#                                              summary             location  \
# 0  First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1  First confirmed imported COVID-19 pneumonia pa...             Shanghai
# 2  First confirmed imported cases in Zhejiang: pa...             Zhejiang
# 3  new confirmed imported COVID-19 pneumonia in T...              Tianjin
# 4  new confirmed imported COVID-19 pneumonia in T...              Tianjin
#
#           country   age symptom_onset  If_onset_approximated hosp_visit_date  \
# 0  Mainland China  66.0      01/03/20                    0.0        01/11/20
# 1  Mainland China  56.0     1/15/2020                    0.0       1/15/2020
# ...

# %%
line_df[line_df['country'].isin(top_countries_list)]['country'].value_counts().count()
# Out:
# 34

# %%
len(top_countries_list)
# Out:
# 40

# %%
list_check = []
for c in list(top_countries_list):
    if c not in line_df[line_df['country'].isin(top_countries_list)]['country'].value_counts().index:
        list_check.append(c)

# %%
list_check
# Out:
# ['Philippines',
#  'Dominican Republic',
#  'Hungary',
#  'Pakistan',
#  'Colombia',
#  'Ukraine']

# %%
top_line_df = line_df[line_df['country'].isin(top_countries)].groupby('country').mean().reset_index()

# %%
top_line_df
# Out:
#           country      id  case_in_country        age  If_onset_approximated  \
# 0         Belgium  1032.0              1.0        NaN                    NaN
# 1          France   217.0             20.0  46.611111               0.200000
# 2         Germany   822.5             27.5  40.214286               0.000000
# 3            Iran  1042.5              9.5        NaN                    NaN
# 4           Italy   966.0              2.0  35.000000                    NaN
# 5  Mainland China    99.0              NaN  49.000000               0.000000
# 6           Spain  1013.5             17.5  43.809524                    NaN
# 7              UK   979.5             10.5  53.000000                    NaN
# 8              US   741.5              9.5  50.000000               0.428571
#
#    visiting Wuhan  from Wuhan
# 0        1.000000    0.000000
# 1        0.051282    0.076923
# 2        0.037037    0.000000
# 3        0.000000    0.000000
# 4        1.000000    0.000000
# ...

# %%
neth = pd.DataFrame(data = [['Netherlands',np.nan,np.nan,np.nan,np.nan,np.nan,np.nan]],columns = top_line_df.columns)

# %%
top_line_df = top_line_df.append(neth)

# %%
top_line_df.reset_index(inplace= True)

# %%
top_line_df
# Out:
#    index         country      id  case_in_country        age  \
# 0      0         Belgium  1032.0              1.0        NaN
# 1      1          France   217.0             20.0  46.611111
# 2      2         Germany   822.5             27.5  40.214286
# 3      3            Iran  1042.5              9.5        NaN
# 4      4           Italy   966.0              2.0  35.000000
# 5      5  Mainland China    99.0              NaN  49.000000
# 6      6           Spain  1013.5             17.5  43.809524
# 7      7              UK   979.5             10.5  53.000000
# 8      8              US   741.5              9.5  50.000000
# 9      0     Netherlands     NaN              NaN        NaN
#
#    If_onset_approximated  visiting Wuhan  from Wuhan
# 0                    NaN        1.000000    0.000000
# 1               0.200000        0.051282    0.076923
# 2               0.000000        0.037037    0.000000
# 3                    NaN        0.000000    0.000000
# ...

# %%
final_df
# Out:
#    Country/Region ObservationDate     SNo  Confirmed   Deaths  Recovered
# 0         Belgium      04/01/2020   10687    13964.0    828.0     2132.0
# 1          France      04/01/2020  108981    57749.0   4043.0    11053.0
# 2         Germany      04/01/2020   10733    77872.0    920.0    18700.0
# 3            Iran      04/01/2020   10748    47593.0   3036.0    15473.0
# 4           Italy      04/01/2020   10752   110574.0  13155.0    16847.0
# 5  Mainland China      04/01/2020  338397    81555.0   3312.0    76248.0
# 6     Netherlands      04/01/2020   43469    13696.0   1175.0      260.0
# 7           Spain      04/01/2020   10822   104118.0   9387.0    22647.0
# 8              UK      04/01/2020  108802    29865.0   2357.0      179.0
# 9              US      04/01/2020  633278   213372.0   4757.0     8474.0

# %%
top_line_df.rename(mapper={'country':'Country/Region'},axis = 1,inplace = True)

# %%
top_line_df.drop('index',axis = 1,inplace = True)

# %%
top_line_df
# Out:
#    Country/Region      id  case_in_country        age  If_onset_approximated  \
# 0         Belgium  1032.0              1.0        NaN                    NaN
# 1          France   217.0             20.0  46.611111               0.200000
# 2         Germany   822.5             27.5  40.214286               0.000000
# 3            Iran  1042.5              9.5        NaN                    NaN
# 4           Italy   966.0              2.0  35.000000                    NaN
# 5  Mainland China    99.0              NaN  49.000000               0.000000
# 6           Spain  1013.5             17.5  43.809524                    NaN
# 7              UK   979.5             10.5  53.000000                    NaN
# 8              US   741.5              9.5  50.000000               0.428571
# 9     Netherlands     NaN              NaN        NaN                    NaN
#
#    visiting Wuhan  from Wuhan
# 0        1.000000    0.000000
# 1        0.051282    0.076923
# ...

# %%
final_df_check = final_df.merge(right = top_line_df,how = 'left',left_on= final_df['Country/Region'],right_on = top_line_df['Country/Region'])

# %%
final_df_check
# Out:
#             key_0 Country/Region_x ObservationDate     SNo  Confirmed  \
# 0         Belgium          Belgium      04/01/2020   10687    13964.0
# 1          France           France      04/01/2020  108981    57749.0
# 2         Germany          Germany      04/01/2020   10733    77872.0
# 3            Iran             Iran      04/01/2020   10748    47593.0
# 4           Italy            Italy      04/01/2020   10752   110574.0
# 5  Mainland China   Mainland China      04/01/2020  338397    81555.0
# 6     Netherlands      Netherlands      04/01/2020   43469    13696.0
# 7           Spain            Spain      04/01/2020   10822   104118.0
# 8              UK               UK      04/01/2020  108802    29865.0
# 9              US               US      04/01/2020  633278   213372.0
#
#     Deaths  Recovered Country/Region_y      id  case_in_country        age  \
# 0    828.0     2132.0          Belgium  1032.0              1.0        NaN
# ...

# %%
final_df_check.drop(['key_0','Country/Region_y'],axis = 1,inplace = True)
